# %% [markdown]
# Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# Read the source data, the data file was already uploaded the colab and file name is IMB881-XLS-ENG.xlsx

# %%
df = pd.read_excel('IMB881-XLS-ENG.xlsx', sheet_name="Raw Data-Order and Sample")
df.head
# Out:
# <bound method NDFrame.head of        OrderType OrderCategory CustomerCode CountryName CustomerOrderNo  \
# 0      Area Wise         Order          H-1         USA       1873354.0
# 1      Area Wise         Order          H-1         USA       1873354.0
# 2      Area Wise         Order          H-1         USA       1873354.0
# 3      Area Wise         Order          H-1         USA       1918436.0
# 4      Area Wise         Order          H-1         USA       1873354.0
# ...          ...           ...          ...         ...             ...
# 18950  Area Wise        Sample          T-2       ITALY          S 1278
# 18951  Area Wise        Sample          T-2       ITALY          S 1278
# 18952  Area Wise        Sample          T-2       ITALY          S 1278
# 18953  Area Wise        Sample          A-9         USA          S 1280
# 18954  Area Wise        Sample           CC       INDIA          S 1281
#
# ...

# %% [markdown]
# corrilation of all the factors to Order Amount and Total area

# %%
x=df.iloc[:,1:3]
x
# Out:
#       OrderCategory CustomerCode
# 0             Order          H-1
# 1             Order          H-1
# 2             Order          H-1
# 3             Order          H-1
# 4             Order          H-1
# ...             ...          ...
# 18950        Sample          T-2
# 18951        Sample          T-2
# 18952        Sample          T-2
# 18953        Sample          A-9
# 18954        Sample           CC
#
# [18955 rows x 2 columns]

# %%
y=df['QtyRequired']
y
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        5.0
# 4        5.0
#         ...
# 18950    1.0
# 18951    1.0
# 18952    1.0
# 18953    2.0
# 18954    1.0
# Name: QtyRequired, Length: 18955, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.30, random_state=42)

# %%
corelation= X_train.corr()
corelation
data_frame=df.apply(lambda X_train: X_train.factorize()[0]).corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data_frame)
